# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.6/dist-packages (4.1.2.30)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.6/dist-packages (from opencv-python) (1.18.5)

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
import cv2

# Load the cascade
face_cascade = cv2.CascadeClassifier('/content/gdrive/My Drive/file.xml')
# Read the input image
img = cv2.imread('/content/gdrive/My Drive/f/harry.jpg')
# Convert into grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# Detect faces
faces = face_cascade.detectMultiScale(gray, 1.1, 2)
# Draw rectangle around the faces
for (x, y, w, h) in faces:
    cv2.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 2)
    #a = a+1
    #cv2.imwrite((imwrite(a,[a,'/content/gdrive/My Drive/f/.jpg']), img[y:y+h, x:x+w])

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=602x474 at 0x7FCCA4A360F0>

# %%
cv2.waitKey()
# Out:
# -1

# %%
cv2.imwrite('/content/gdrive/My Drive/f/crop.jpg', img[y:y+h, x:x+w])
# Out:
# True

# %%
c = cv2.imread('/content/gdrive/My Drive/f/crop.jpg')
gray = cv2.cvtColor(c, cv2.COLOR_BGR2GRAY)
faces = face_cascade.detectMultiScale(gray, 1.1, 2)

# %%
cv2_imshow(c)
# Out:
# <PIL.Image.Image image mode=RGB size=88x88 at 0x7FCCA49DB3C8>

# %%
img
# Out:
# array([[[185, 183, 153],
#         [186, 184, 154],
#         [187, 185, 155],
#         ...,
#         [ 89,  89,  65],
#         [ 88,  88,  64],
#         [ 87,  87,  63]],
#
#        [[212, 209, 181],
#         [209, 206, 178],
#         [204, 201, 173],
#         ...,
#         [ 90,  90,  66],
#         [ 89,  89,  65],
#         [ 89,  89,  65]],
#
#        [[240, 239, 213],
#         [238, 237, 211],
#         [235, 234, 208],
#         ...,
#         [ 92,  92,  68],
#         [ 91,  91,  67],
#         [ 91,  91,  67]],
#
#        ...,
#
#        [[ 80,  95, 114],
#         [ 77,  92, 111],
#         [ 73,  88, 107],
#         ...,
#         [ 67,  78,  98],
#         [ 74,  85, 105],
#         [ 77,  88, 108]],
#
#        [[ 86, 101, 120],
#         [ 81,  96, 115],
#         [ 74,  89, 108],
#         ...,
#         [ 61,  72,  92],
#         [ 64,  75,  95],
#         [ 65,  76,  96]],
#
#        [[ 80,  95, 114],
#         [ 83,  98, 117],
#         [ 80,  95, 114],
#         ...,
#         [ 67,  78,  98],
#         [ 61,  72,  92],
#         [ 58,  69,  89]]], dtype=uint8)

# %%
from cv2 import imread
from cv2 import CascadeClassifier
# load the photograph
pixels = imread('/content/gdrive/My Drive/f/h.jpg')
# load the pre-trained model
classifier = CascadeClassifier('/content/gdrive/My Drive/file.xml')
# perform face detection
bboxes = classifier.detectMultiScale(pixels)
# print bounding box for each detected face
for box in bboxes:
	print(box)
# Out:
# [462  80  34  34]
# [253  95  27  27]
# [322 107  31  31]
# [167 107  27  27]
# [398 108  29  29]
# [ 11 260  68  68]

# %%
for i in range(0, img.shape[2]):
  box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
  (startX, startY, endX, endY) = box.astype("int")

  confidence = detections[0, 0, i, 2]

  # If confidence > 0.5, save it as a separate file
  if (confidence > 0.5):
    count += 1
    frame = image[startY:endY, startX:endX]
    cv2.imwrite(base_dir + 'faces/' + str(i) + '_' + file, frame)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-66560845407a> in <module>()
# ----> 1 for i in range(0, detections.shape[2]):
#       2   box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
#       3   (startX, startY, endX, endY) = box.astype("int")
#       4
#       5   confidence = detections[0, 0, i, 2]
#
# NameError: name 'detections' is not defined
